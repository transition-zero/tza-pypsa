# %%
import tz_pypsa
import pandas as pd
from tz_pypsa.model import Model
import numpy as np
import matplotlib.pyplot as plt
import plotly.express as px
import plotly.graph_objects as go

# %%
n=Model.load_csv_from_dir('./stock_models/Taiwan',
                          year=2023,
                          frequency='1h',
                          timesteps=8760,
                          backstop=False)
# Out:
# WARNING:pypsa.io:Importing network from PyPSA version v? while current version is v0.33.0. Read the release notes at https://pypsa.readthedocs.io/en/latest/release_notes.html to prepare your network for import.
# INFO:pypsa.networks:Repeating time-series for each investment period and converting snapshots to a pandas.MultiIndex.
# INFO:pypsa.io:Imported network Taiwan has buses, carriers, generators, loads, storage_units

# %%
n.optimize(solver_name='highs')
# Out:
# INFO:linopy.model: Solve problem using Highs solver
# INFO:linopy.io:Writing objective.
# Writing constraints.: 100%|██████████| 12/12 [00:01<00:00, 10.61it/s]
# Writing continuous variables.: 100%|██████████| 5/5 [00:00<00:00, 20.95it/s]
# INFO:linopy.io: Writing time: 1.51s
# INFO:linopy.constants: Optimization successful:
# Status: ok
# Termination condition: optimal
# Solution: 87601 primals, 192721 duals
# Objective: 5.92e+08
# Solver model: available
# Solver message: optimal
#
# INFO:pypsa.optimization.optimize:The shadow-prices of the constraints Generator-fix-p-lower, Generator-fix-p-upper, StorageUnit-ext-p_dispatch-lower, StorageUnit-ext-p_dispatch-upper, StorageUnit-ext-p_store-lower, StorageUnit-ext-p_store-upper, StorageUnit-ext-state_of_charge-lower, StorageUnit-ext-state_of_charge-upper, StorageUnit-energy_balance were not assigned to the network.
# ('ok', 'optimal')

# %%
import tz_pypsa.wrangle as wrangle

# %%
wrangle.export_long_format(n, 'twn_sample_vis_output', 'csv')
# Out:
#                  timestep         Value        type node       tech  Hour  \
# 0     2023-01-01 00:00:00  23235.666667      Demand  TWN        NaN     0
# 1     2023-01-01 00:00:00  14710.000000  Generation  TWN       Coal     0
# 2     2023-01-01 00:00:00   2069.833333  Generation  TWN        LNG     0
# 3     2023-01-01 00:00:00     -0.000000  Generation  TWN        Oil     0
# 4     2023-01-01 00:00:00   3872.000000  Generation  TWN    Nuclear     0
# ...                   ...           ...         ...  ...        ...   ...
# 78835 2023-12-31 23:00:00   3872.000000  Generation  TWN    Nuclear    23
# 78836 2023-12-31 23:00:00   2101.000000  Generation  TWN      Hydro    23
# 78837 2023-12-31 23:00:00    257.000000  Generation  TWN       Wind    23
# 78838 2023-12-31 23:00:00     -0.000000  Generation  TWN      Solar    23
# 78839 2023-12-31 23:00:00      0.000000     Storage  TWN  Batteries    23
#
#        Month  Year
# 0          1  2023
# 1          1  2023
# 2          1  2023
# 3          1  2023
# 4          1  2023
# ...      ...   ...
# 78835     12  2023
# 78836     12  2023
# 78837     12  2023
# 78838     12  2023
# 78839     12  2023
#
# [78840 rows x 8 columns]
