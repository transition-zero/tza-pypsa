# %%
import tz_pypsa
import pandas as pd
import numpy as np
from tz_pypsa.model import Model
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 import tz_pypsa
#       2 import pandas as pd
#       3 import numpy as np
#
# ModuleNotFoundError: No module named 'tz_pypsa'

# %%
n=Model.load_csv_from_dir('./stock_models/Taiwan',
                          year=2023,
                          frequency='1h',
                          timesteps=8760,
                          backstop=False)

# %%
n.optimize(solver_name='highs')

# %%
import tz_pypsa.wrangle as wrangle

# %%
wrangle.export_csv_consolidated(n, 'twn_sample_vis_output.csv')
